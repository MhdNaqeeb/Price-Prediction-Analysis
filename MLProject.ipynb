# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')
# Out:
# C:\Users\Mhd Naqeeb\AppData\Local\Temp\ipykernel_3588\1422964994.py:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
data = pd.read_csv('E:\DataProjects\DOGE-USD.csv')
print(data.head())
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2022-06-01  0.085855  0.088647  0.079807  0.081056   0.081056  830748610
# 1  2022-06-02  0.081052  0.083007  0.080417  0.082772   0.082772  434510607
# 2  2022-06-03  0.082777  0.082857  0.079756  0.080442   0.080442  403339248
# 3  2022-06-04  0.080454  0.082337  0.079727  0.081777   0.081777  350329772
# 4  2022-06-05  0.081776  0.082138  0.080836  0.081229   0.081229  282624184

# %%
data.dropna()
# Out:
#            Date      Open      High       Low     Close  Adj Close     Volume
# 0    2022-06-01  0.085855  0.088647  0.079807  0.081056   0.081056  830748610
# 1    2022-06-02  0.081052  0.083007  0.080417  0.082772   0.082772  434510607
# 2    2022-06-03  0.082777  0.082857  0.079756  0.080442   0.080442  403339248
# 3    2022-06-04  0.080454  0.082337  0.079727  0.081777   0.081777  350329772
# 4    2022-06-05  0.081776  0.082138  0.080836  0.081229   0.081229  282624184
# ..          ...       ...       ...       ...       ...        ...        ...
# 361  2023-05-28  0.072681  0.073917  0.072199  0.073613   0.073613  190660985
# 362  2023-05-29  0.073616  0.073919  0.072831  0.073185   0.073185  157791026
# 363  2023-05-30  0.073183  0.073383  0.072275  0.072361   0.072361  248138018
# 364  2023-05-31  0.072362  0.072633  0.070842  0.071660   0.071660  189603858
# 365  2023-06-01  0.071660  0.071894  0.070883  0.071666   0.071666  151740928
#
# [366 rows x 7 columns]

# %%
plt.figure(figsize=(10, 4))
plt.title("DogeCoin Price INR")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
from autots import AutoTS
model = AutoTS(forecast_length=10, frequency='infer', ensemble='simple', drop_data_older_than_periods=200)
model = model.fit(data, date_col='Date', value_col='Close', id_col=None)

prediction = model.predict()
forecast = prediction.forecast
print("DogeCoin Price Prediction")
print(forecast)
# Out:
# Inferred frequency is: D
# Old data dropped by `drop_data_older_than_periods`.
# Model Number: 1 with model ARIMA in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model AverageValueNaive in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 8 with model DatepartRegression in generation 0 of 10
# Epoch 1/50
# 6/6 [==============================] - 51s 40ms/step - loss: 0.0014
# Epoch 2/50
# 6/6 [==============================] - 0s 20ms/step - loss: 6.2948e-04
# Epoch 3/50
# 6/6 [==============================] - 0s 20ms/step - loss: 3.7139e-04
# Epoch 4/50
# 6/6 [==============================] - 0s 18ms/step - loss: 2.4605e-04
# Epoch 5/50
# 6/6 [==============================] - 0s 22ms/step - loss: 1.6740e-04
# Epoch 6/50
# 6/6 [==============================] - 0s 26ms/step - loss: 1.7476e-04
# Epoch 7/50
# 6/6 [==============================] - 0s 25ms/step - loss: 1.3145e-04
# Epoch 8/50
# 6/6 [==============================] - 0s 22ms/step - loss: 1.1736e-04
# Epoch 9/50
# 6/6 [==============================] - 0s 24ms/step - loss: 8.6744e-05
# Epoch 10/50
# 6/6 [==============================] - 0s 20ms/step - loss: 6.9094e-05
# Epoch 11/50
# 6/6 [==============================] - 0s 22ms/step - loss: 7.5090e-05
# Epoch 12/50
# 6/6 [==============================] - 0s 25ms/step - loss: 6.8964e-05
# Epoch 13/50
# 6/6 [==============================] - 0s 34ms/step - loss: 5.0700e-05
# Epoch 14/50
# 6/6 [==============================] - 0s 33ms/step - loss: 4.8520e-05
# Epoch 15/50
# 6/6 [==============================] - 0s 19ms/step - loss: 4.4353e-05
# Epoch 16/50
# 6/6 [==============================] - 0s 28ms/step - loss: 4.0352e-05
# Epoch 17/50
# 6/6 [==============================] - 0s 32ms/step - loss: 3.3171e-05
# Epoch 18/50
# 6/6 [==============================] - 0s 21ms/step - loss: 3.0437e-05
# Epoch 19/50
# 6/6 [==============================] - 0s 18ms/step - loss: 2.4363e-05
# Epoch 20/50
# 6/6 [==============================] - 0s 21ms/step - loss: 2.3392e-05
# Epoch 21/50
# 6/6 [==============================] - 0s 19ms/step - loss: 1.9815e-05
# Epoch 22/50
# 6/6 [==============================] - 0s 19ms/step - loss: 1.6771e-05
# Epoch 23/50
# 6/6 [==============================] - 0s 18ms/step - loss: 1.9311e-05
# Epoch 24/50
# 6/6 [==============================] - 0s 28ms/step - loss: 1.6557e-05
# Epoch 25/50
# 6/6 [==============================] - 0s 19ms/step - loss: 1.7878e-05
# Epoch 26/50
# 6/6 [==============================] - 0s 16ms/step - loss: 1.4425e-05
# Epoch 27/50
# 6/6 [==============================] - 0s 17ms/step - loss: 1.3125e-05
# Epoch 28/50
# 6/6 [==============================] - 0s 17ms/step - loss: 1.3241e-05
# Epoch 29/50
# 6/6 [==============================] - 0s 17ms/step - loss: 1.4171e-05
# Epoch 30/50
# 6/6 [==============================] - 0s 18ms/step - loss: 9.8934e-06
# Epoch 31/50
# 6/6 [==============================] - 0s 19ms/step - loss: 8.8901e-06
# Epoch 32/50
# 6/6 [==============================] - 0s 21ms/step - loss: 7.2622e-06
# Epoch 33/50
# 6/6 [==============================] - 0s 18ms/step - loss: 8.1896e-06
# Epoch 34/50
# 6/6 [==============================] - 0s 17ms/step - loss: 6.4291e-06
# Epoch 35/50
# 6/6 [==============================] - 0s 20ms/step - loss: 6.4848e-06
# Epoch 36/50
# 6/6 [==============================] - 0s 19ms/step - loss: 7.2029e-06
# Epoch 37/50
# 6/6 [==============================] - 0s 23ms/step - loss: 5.4441e-06
# Epoch 38/50
# 6/6 [==============================] - 0s 19ms/step - loss: 6.5106e-06
# Epoch 39/50
# 6/6 [==============================] - 0s 21ms/step - loss: 7.5557e-06
# Epoch 40/50
# 6/6 [==============================] - 0s 19ms/step - loss: 5.7664e-06
# Epoch 41/50
# 6/6 [==============================] - 0s 19ms/step - loss: 5.1230e-06
# Epoch 42/50
# 6/6 [==============================] - 0s 18ms/step - loss: 5.1495e-06
# Epoch 43/50
# 6/6 [==============================] - 0s 19ms/step - loss: 3.4107e-06
# Epoch 44/50
# 6/6 [==============================] - 0s 19ms/step - loss: 4.4106e-06
# Epoch 45/50
# 6/6 [==============================] - 0s 18ms/step - loss: 4.9522e-06
# Epoch 46/50
# 6/6 [==============================] - 0s 15ms/step - loss: 3.6922e-06
# Epoch 47/50
# 6/6 [==============================] - 0s 16ms/step - loss: 4.1087e-06
# Epoch 48/50
# 6/6 [==============================] - 0s 16ms/step - loss: 3.7557e-06
# Epoch 49/50
# 6/6 [==============================] - 0s 17ms/step - loss: 3.4679e-06
# Epoch 50/50
# 6/6 [==============================] - 0s 14ms/step - loss: 3.5905e-06
# 1/1 [==============================] - 6s 6s/step
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: divide by zero encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:66: RuntimeWarning: invalid value encountered in divide
#   post_mu = (
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: divide by zero encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:66: RuntimeWarning: invalid value encountered in divide
#   post_mu = (
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: divide by zero encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:66: RuntimeWarning: invalid value encountered in divide
#   post_mu = (
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: divide by zero encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in add
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: divide by zero encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in add
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: divide by zero encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in add
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: divide by zero encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:66: RuntimeWarning: invalid value encountered in divide
#   post_mu = (
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: divide by zero encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:66: RuntimeWarning: invalid value encountered in divide
#   post_mu = (
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: divide by zero encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:66: RuntimeWarning: invalid value encountered in divide
#   post_mu = (
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: divide by zero encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in add
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# Model Number: 9 with model ETS in generation 0 of 10
# Model Number: 10 with model ETS in generation 0 of 10
# Model Number: 11 with model GLM in generation 0 of 10
# Model Number: 12 with model GLM in generation 0 of 10
# Model Number: 13 with model GLS in generation 0 of 10
# Model Number: 14 with model GLS in generation 0 of 10
# Model Number: 15 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue.') in model 15 in generation 0: GluonTS
# Model Number: 16 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue.') in model 16 in generation 0: GluonTS
# Model Number: 17 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue.') in model 17 in generation 0: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue.') in model 18 in generation 0: GluonTS
# Model Number: 19 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue.') in model 19 in generation 0: GluonTS
# Model Number: 20 with model LastValueNaive in generation 0 of 10
# Model Number: 21 with model LastValueNaive in generation 0 of 10
# Model Number: 22 with model LastValueNaive in generation 0 of 10
# Model Number: 23 with model LastValueNaive in generation 0 of 10
# Model Number: 24 with model SeasonalNaive in generation 0 of 10
# Model Number: 25 with model SeasonalNaive in generation 0 of 10
# Model Number: 26 with model SeasonalNaive in generation 0 of 10
# Model Number: 27 with model UnobservedComponents in generation 0 of 10
# Model Number: 28 with model UnobservedComponents in generation 0 of 10
# Model Number: 29 with model UnobservedComponents in generation 0 of 10
# Model Number: 30 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 30 in generation 0: VAR
# Model Number: 31 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 31 in generation 0: VAR
# Model Number: 32 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 32 in generation 0: VECM
# Model Number: 33 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 33 in generation 0: VECM
# Model Number: 34 with model WindowRegression in generation 0 of 10
# Model Number: 35 with model ConstantNaive in generation 0 of 10
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 36 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 36 in generation 0: FBProphet
# Model Number: 37 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue.') in model 37 in generation 0: GluonTS
# Model Number: 38 with model MultivariateRegression in generation 0 of 10
# Model Number: 39 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 39 in generation 0: MultivariateRegression
# Model Number: 40 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 40 in generation 0: DatepartRegression
# Model Number: 41 with model SeasonalNaive in generation 0 of 10
# Model Number: 42 with model DatepartRegression in generation 0 of 10
# Model Number: 43 with model UnobservedComponents in generation 0 of 10
# Model Number: 44 with model UnobservedComponents in generation 0 of 10
# Model Number: 45 with model ETS in generation 0 of 10
# Model Number: 46 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 46 in generation 0: VECM
# Model Number: 47 with model ARDL in generation 0 of 10
# Model Number: 48 with model MultivariateMotif in generation 0 of 10
# Model Number: 49 with model MultivariateMotif in generation 0 of 10
# Model Number: 50 with model UnivariateMotif in generation 0 of 10
# Model Number: 51 with model UnivariateMotif in generation 0 of 10
# Model Number: 52 with model SectionalMotif in generation 0 of 10
# Model Number: 53 with model SectionalMotif in generation 0 of 10
# Model Number: 54 with model MultivariateRegression in generation 0 of 10
# Model Number: 55 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 55 in generation 0: FBProphet
# Model Number: 56 with model SeasonalNaive in generation 0 of 10
# Model Number: 57 with model DatepartRegression in generation 0 of 10
# Model Number: 58 with model NVAR in generation 0 of 10
# Model Number: 59 with model Theta in generation 0 of 10
# Model Number: 60 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: ValueError('Input X contains NaN.\nDecisionTreeRegressor does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values') in model 60 in generation 0: UnivariateRegression
# Model Number: 61 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 61 in generation 0: ARCH
# Model Number: 62 with model ConstantNaive in generation 0 of 10
# Model Number: 63 with model LastValueNaive in generation 0 of 10
# Model Number: 64 with model AverageValueNaive in generation 0 of 10
# Model Number: 65 with model GLS in generation 0 of 10
# Model Number: 66 with model SeasonalNaive in generation 0 of 10
# Model Number: 67 with model GLM in generation 0 of 10
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\genmod\families\family.py:1342: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
# Model Number: 68 with model ETS in generation 0 of 10
# Model Number: 69 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 69 in generation 0: FBProphet
# Model Number: 70 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue.') in model 70 in generation 0: GluonTS
# Model Number: 71 with model UnobservedComponents in generation 0 of 10
# Model Number: 72 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 72 in generation 0: VAR
# Model Number: 73 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 73 in generation 0: VECM
# Model Number: 74 with model ARIMA in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 74 in generation 0: ARIMA
# Model Number: 75 with model WindowRegression in generation 0 of 10
# Model Number: 76 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 76 in generation 0: DatepartRegression
# Model Number: 77 with model UnivariateRegression in generation 0 of 10
# Model Number: 78 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'xgboost'") in model 78 in generation 0: MultivariateRegression
# Model Number: 79 with model UnivariateMotif in generation 0 of 10
# Model Number: 80 with model MultivariateMotif in generation 0 of 10
# Model Number: 81 with model SectionalMotif in generation 0 of 10
# Model Number: 82 with model NVAR in generation 0 of 10
# Model Number: 83 with model Theta in generation 0 of 10
# Model Number: 84 with model ARDL in generation 0 of 10
# HolidayTransformer: no anomalies detected.
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 84 in generation 0: ARDL
# Model Number: 85 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 85 in generation 0: ARCH
# Model Number: 86 with model MetricMotif in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 86 in generation 0: MetricMotif
# Model Number: 87 with model ETS in generation 0 of 10
# Model Number: 88 with model ETS in generation 0 of 10
# ETS error ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# ETS failed on Close with ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# Model Number: 89 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 89 in generation 0: GLM
# Model Number: 90 with model ETS in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 90 in generation 0: ETS
# Model Number: 91 with model ConstantNaive in generation 0 of 10
# Model Number: 92 with model MultivariateMotif in generation 0 of 10
# Model Number: 93 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 93 in generation 0: ARDL
# Model Number: 94 with model GLM in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 94 in generation 0: GLM
# Model Number: 95 with model SectionalMotif in generation 0 of 10
# Model Number: 96 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 96 in generation 0: ARDL
# Model Number: 97 with model NVAR in generation 0 of 10
# Model Number: 98 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 98 in generation 0: VAR
# Model Number: 99 with model UnivariateMotif in generation 0 of 10
# Model Number: 100 with model MetricMotif in generation 0 of 10
# Model Number: 101 with model ConstantNaive in generation 0 of 10
# Model Number: 102 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 102 in generation 0: VECM
# Model Number: 103 with model SeasonalNaive in generation 0 of 10
# Model Number: 104 with model AverageValueNaive in generation 0 of 10
# Model Number: 105 with model DatepartRegression in generation 0 of 10
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model Number: 106 with model ETS in generation 0 of 10
# ETS error ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# ETS failed on Close with ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# Template Eval Error: ValueError("Model returned NaN due to a preprocessing transformer {'fillna': 'rolling_mean_24', 'transformations': {'0': 'ClipOutliers', '1': 'Detrend', '2': 'cffilter', '3': 'AlignLastValue'}, 'transformation_params': {'0': {'method': 'clip', 'std_threshold': 5, 'fillna': None}, '1': {'model': 'Linear', 'phi': 1, 'window': None, 'transform_dict': None}, '2': {}, '3': {'rows': 1, 'lag': 1, 'method': 'multiplicative', 'strength': 1.0, 'first_value_only': False}}}. fail_on_forecast_nan=True") in model 106 in generation 0: ETS
# Model Number: 107 with model UnobservedComponents in generation 0 of 10
# Model Number: 108 with model NVAR in generation 0 of 10
# Model Number: 109 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue.') in model 109 in generation 0: GluonTS
# Model Number: 110 with model LastValueNaive in generation 0 of 10
# Model Number: 111 with model DatepartRegression in generation 0 of 10
# Model Number: 112 with model MultivariateRegression in generation 0 of 10
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model Number: 113 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 113 in generation 0: VAR
# Model Number: 114 with model ETS in generation 0 of 10
# Model Number: 115 with model ETS in generation 0 of 10
# Model Number: 116 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 116 in generation 0: UnobservedComponents
# Model Number: 117 with model ETS in generation 0 of 10
# ETS error ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# ETS failed on Close with ValueError('Cannot compute initial seasonals using heuristic method with less than two full seasonal cycles in the data.')
# Model Number: 118 with model SeasonalNaive in generation 0 of 10
# Model Number: 119 with model ARIMA in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 119 in generation 0: ARIMA
# Model Number: 120 with model SeasonalNaive in generation 0 of 10
# Model Number: 121 with model GLS in generation 0 of 10
# Model Number: 122 with model UnivariateMotif in generation 0 of 10
# Model Number: 123 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 123 in generation 0: VAR
# Model Number: 124 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue.') in model 124 in generation 0: GluonTS
# Model Number: 125 with model ConstantNaive in generation 0 of 10
# Model Number: 126 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 126 in generation 0: ARCH
# Model Number: 127 with model Theta in generation 0 of 10
# Model Number: 128 with model ARDL in generation 0 of 10
# Model Number: 129 with model SectionalMotif in generation 0 of 10
# Model Number: 130 with model Theta in generation 0 of 10
# Model Number: 131 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 131 in generation 0: DatepartRegression
# Model Number: 132 with model UnobservedComponents in generation 0 of 10
# Model Number: 133 with model WindowRegression in generation 0 of 10
# Model Number: 134 with model GLS in generation 0 of 10
# Model Number: 135 with model LastValueNaive in generation 0 of 10
# Model Number: 136 with model NVAR in generation 0 of 10
# Model Number: 137 with model MultivariateMotif in generation 0 of 10
# Model Number: 138 with model ARIMA in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 138 in generation 0: ARIMA
# Model Number: 139 with model ETS in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 139 in generation 0: ETS
# Model Number: 140 with model ConstantNaive in generation 0 of 10
# Model Number: 141 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 141 in generation 0: MultivariateRegression
# Model Number: 142 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 142 in generation 0: VAR
# Model Number: 143 with model NVAR in generation 0 of 10
# Model Number: 144 with model SeasonalNaive in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 144 in generation 0: SeasonalNaive
# Model Number: 145 with model LastValueNaive in generation 0 of 10
# Model Number: 146 with model LastValueNaive in generation 0 of 10
# Model Number: 147 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 147 in generation 0: FBProphet
# Model Number: 148 with model LastValueNaive in generation 0 of 10
# Model Number: 149 with model SeasonalNaive in generation 0 of 10
# Model Number: 150 with model NVAR in generation 0 of 10
# Model Number: 151 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'lightgbm'") in model 151 in generation 0: MultivariateRegression
# Model Number: 152 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 152 in generation 0: VECM
# Model Number: 153 with model NVAR in generation 0 of 10
# Model Number: 154 with model AverageValueNaive in generation 0 of 10
# Model Number: 155 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 155 in generation 0: ARCH
# Model Number: 156 with model ARDL in generation 0 of 10
# Model Number: 157 with model MetricMotif in generation 0 of 10
# Model Number: 158 with model ConstantNaive in generation 0 of 10
# Model Number: 159 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 159 in generation 0: DatepartRegression
# Model Number: 160 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 160 in generation 0: ARDL
# Model Number: 161 with model Theta in generation 0 of 10
# Model Number: 162 with model GLS in generation 0 of 10
# Model Number: 163 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 163 in generation 0: UnivariateRegression
# Model Number: 164 with model ARDL in generation 0 of 10
# Model Number: 165 with model GLS in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 165 in generation 0: GLS
# Model Number: 166 with model AverageValueNaive in generation 0 of 10
# Model Number: 167 with model GLM in generation 0 of 10
# Model Number: 168 with model LastValueNaive in generation 0 of 10
# Model Number: 169 with model AverageValueNaive in generation 0 of 10
# Model Number: 170 with model UnivariateMotif in generation 0 of 10
# Model Number: 171 with model Theta in generation 0 of 10
# Model Number: 172 with model GLM in generation 0 of 10
# Model Number: 173 with model MultivariateMotif in generation 0 of 10
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:298: DomainWarning: The inverse_power link function does not respect the domain of the Gamma family.
#   warnings.warn((f"The {type(family.link).__name__} link function "
# Model Number: 174 with model Theta in generation 0 of 10
# Model Number: 175 with model ARDL in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 175 in generation 0: ARDL
# Model Number: 176 with model DatepartRegression in generation 0 of 10
# Model Number: 177 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 177 in generation 0: UnobservedComponents
# Model Number: 178 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 178 in generation 0: UnobservedComponents
# Model Number: 179 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue.') in model 179 in generation 0: GluonTS
# Model Number: 180 with model GLS in generation 0 of 10
# Model Number: 181 with model SeasonalNaive in generation 0 of 10
# Model Number: 182 with model MultivariateMotif in generation 0 of 10
# Model Number: 183 with model ConstantNaive in generation 0 of 10
# Model Number: 184 with model Theta in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 184 in generation 0: Theta
# Model Number: 185 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue.') in model 185 in generation 0: GluonTS
# Model Number: 186 with model LastValueNaive in generation 0 of 10
# New Generation: 1 of 10
# Model Number: 187 with model LastValueNaive in generation 1 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 187 in generation 1: LastValueNaive
# Model Number: 188 with model GLM in generation 1 of 10
# HolidayTransformer: no anomalies detected.
# Model Number: 189 with model LastValueNaive in generation 1 of 10
# Model Number: 190 with model ETS in generation 1 of 10
# Model Number: 191 with model Theta in generation 1 of 10
# Model Number: 192 with model DatepartRegression in generation 1 of 10
# Model Number: 193 with model GLS in generation 1 of 10
# Model Number: 194 with model DatepartRegression in generation 1 of 10
# Model Number: 195 with model Theta in generation 1 of 10
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\decomposition\_fastica.py:708: FutureWarning: Starting in v1.3, whiten=True should be specified as whiten='arbitrary-variance' (its current behaviour). This behavior is deprecated in 1.1 and will raise ValueError in 1.3.
#   return self._fit_transform(X, compute_sources=True)
# Model Number: 196 with model UnivariateMotif in generation 1 of 10
# Model Number: 197 with model LastValueNaive in generation 1 of 10
# Model Number: 198 with model ConstantNaive in generation 1 of 10
# Model Number: 199 with model AverageValueNaive in generation 1 of 10
# Model Number: 200 with model UnobservedComponents in generation 1 of 10
# Model Number: 201 with model MultivariateMotif in generation 1 of 10
# Model Number: 202 with model MultivariateMotif in generation 1 of 10
# Model Number: 203 with model MultivariateMotif in generation 1 of 10
# Model Number: 204 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 204 in generation 1: UnobservedComponents
# Model Number: 205 with model LastValueNaive in generation 1 of 10
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.9047e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# Model Number: 206 with model ARDL in generation 1 of 10
# Model Number: 207 with model NVAR in generation 1 of 10
# Model Number: 208 with model AverageValueNaive in generation 1 of 10
# Model Number: 209 with model UnivariateMotif in generation 1 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 209 in generation 1: UnivariateMotif
# Model Number: 210 with model SeasonalNaive in generation 1 of 10
# Model Number: 211 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 211 in generation 1: UnobservedComponents
# Model Number: 212 with model NVAR in generation 1 of 10
# Model Number: 213 with model UnivariateMotif in generation 1 of 10
# Model Number: 214 with model SectionalMotif in generation 1 of 10
# Model Number: 215 with model WindowRegression in generation 1 of 10
# HolidayTransformer: no anomalies detected.
# Model Number: 216 with model MultivariateRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 216 in generation 1: MultivariateRegression
# Model Number: 217 with model UnivariateMotif in generation 1 of 10
# Model Number: 218 with model MultivariateRegression in generation 1 of 10
# Model Number: 219 with model Theta in generation 1 of 10
# Model Number: 220 with model ConstantNaive in generation 1 of 10
# Model Number: 221 with model Theta in generation 1 of 10
# Model Number: 222 with model ARIMA in generation 1 of 10
# Model Number: 223 with model WindowRegression in generation 1 of 10
# Model Number: 224 with model NVAR in generation 1 of 10
# Model Number: 225 with model MetricMotif in generation 1 of 10
# Model Number: 226 with model UnobservedComponents in generation 1 of 10
# Model Number: 227 with model ConstantNaive in generation 1 of 10
# Model Number: 228 with model ConstantNaive in generation 1 of 10
# Model Number: 229 with model GLS in generation 1 of 10
# Model Number: 230 with model NVAR in generation 1 of 10
# Model Number: 231 with model WindowRegression in generation 1 of 10
# Model Number: 232 with model ConstantNaive in generation 1 of 10
# Model Number: 233 with model ETS in generation 1 of 10
# Model Number: 234 with model LastValueNaive in generation 1 of 10
# Model Number: 235 with model Theta in generation 1 of 10
# Model Number: 236 with model MultivariateMotif in generation 1 of 10
# Model Number: 237 with model ETS in generation 1 of 10
# Model Number: 238 with model SeasonalNaive in generation 1 of 10
# Model Number: 239 with model SeasonalNaive in generation 1 of 10
# Model Number: 240 with model GLM in generation 1 of 10
# Model Number: 241 with model SeasonalNaive in generation 1 of 10
# Model Number: 242 with model ConstantNaive in generation 1 of 10
# Model Number: 243 with model NVAR in generation 1 of 10
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\decomposition\_fastica.py:708: FutureWarning: Starting in v1.3, whiten=True should be specified as whiten='arbitrary-variance' (its current behaviour). This behavior is deprecated in 1.1 and will raise ValueError in 1.3.
#   return self._fit_transform(X, compute_sources=True)
# Model Number: 244 with model MultivariateMotif in generation 1 of 10
# Model Number: 245 with model SectionalMotif in generation 1 of 10
# Model Number: 246 with model AverageValueNaive in generation 1 of 10
# Model Number: 247 with model Theta in generation 1 of 10
# Model Number: 248 with model SeasonalNaive in generation 1 of 10
# Model Number: 249 with model MetricMotif in generation 1 of 10
# Model Number: 250 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 250 in generation 1: DatepartRegression
# Model Number: 251 with model AverageValueNaive in generation 1 of 10
# Model Number: 252 with model UnobservedComponents in generation 1 of 10
# Model Number: 253 with model LastValueNaive in generation 1 of 10
# Model Number: 254 with model SeasonalNaive in generation 1 of 10
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# Model Number: 255 with model ETS in generation 1 of 10
# Model Number: 256 with model SeasonalNaive in generation 1 of 10
# Model Number: 257 with model AverageValueNaive in generation 1 of 10
# Model Number: 258 with model Theta in generation 1 of 10
# Model Number: 259 with model GLS in generation 1 of 10
# Model Number: 260 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 260 in generation 1: DatepartRegression
# Model Number: 261 with model Theta in generation 1 of 10
# Model Number: 262 with model AverageValueNaive in generation 1 of 10
# Model Number: 263 with model LastValueNaive in generation 1 of 10
# Model Number: 264 with model MultivariateRegression in generation 1 of 10
# Model Number: 265 with model MultivariateMotif in generation 1 of 10
# Model Number: 266 with model SectionalMotif in generation 1 of 10
# Model Number: 267 with model LastValueNaive in generation 1 of 10
# Model Number: 268 with model DatepartRegression in generation 1 of 10
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\decomposition\_fastica.py:708: FutureWarning: Starting in v1.3, whiten=True should be specified as whiten='arbitrary-variance' (its current behaviour). This behavior is deprecated in 1.1 and will raise ValueError in 1.3.
#   return self._fit_transform(X, compute_sources=True)
# Model Number: 269 with model GLS in generation 1 of 10
# Model Number: 270 with model SectionalMotif in generation 1 of 10
# Model Number: 271 with model ARDL in generation 1 of 10
# Model Number: 272 with model ARIMA in generation 1 of 10
# Model Number: 273 with model GLM in generation 1 of 10
# Model Number: 274 with model MultivariateRegression in generation 1 of 10
# Model Number: 275 with model GLM in generation 1 of 10
# Model Number: 276 with model GLS in generation 1 of 10
# Model Number: 277 with model Theta in generation 1 of 10
# Model Number: 278 with model UnobservedComponents in generation 1 of 10
# Model Number: 279 with model LastValueNaive in generation 1 of 10
# Model Number: 280 with model ConstantNaive in generation 1 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 280 in generation 1: ConstantNaive
# Model Number: 281 with model ETS in generation 1 of 10
# Model Number: 282 with model ETS in generation 1 of 10
# Model Number: 283 with model NVAR in generation 1 of 10
# Model Number: 284 with model LastValueNaive in generation 1 of 10
# Model Number: 285 with model ETS in generation 1 of 10
# Model Number: 286 with model AverageValueNaive in generation 1 of 10
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: invalid value encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:67: RuntimeWarning: divide by zero encountered in divide
#   (prior_mu / prior_sigma**2) + ((n * data_mu) / prior_sigma**2)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\autots\tools\probabilistic.py:68: RuntimeWarning: divide by zero encountered in divide
#   ) / ((1 / prior_sigma**2) + (n / prior_sigma**2))
# ...
# 79 - GLS with avg smape 1.37:
# Model Number: 80 of 180 with model ETS for Validation 3
# ETS error ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# ETS failed on Close with ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# 80 - ETS with avg smape 1.37:
# Model Number: 81 of 180 with model ETS for Validation 3
# 81 - ETS with avg smape 1.37:
# Model Number: 82 of 180 with model ETS for Validation 3
# 82 - ETS with avg smape 1.37:
# Model Number: 83 of 180 with model GLS for Validation 3
# 83 - GLS with avg smape 1.37:
# Model Number: 84 of 180 with model GLS for Validation 3
# 84 - GLS with avg smape 1.37:
# Model Number: 85 of 180 with model GLS for Validation 3
# 85 - GLS with avg smape 1.37:
# Model Number: 86 of 180 with model Theta for Validation 3
# 86 - Theta with avg smape 1.42:
# Model Number: 87 of 180 with model LastValueNaive for Validation 3
# 87 - LastValueNaive with avg smape 1.37:
# Model Number: 88 of 180 with model UnivariateMotif for Validation 3
# 88 - UnivariateMotif with avg smape 1.97:
# Model Number: 89 of 180 with model UnivariateMotif for Validation 3
# 89 - UnivariateMotif with avg smape 1.98:
# Model Number: 90 of 180 with model UnobservedComponents for Validation 3
# 90 - UnobservedComponents with avg smape 1.81:
# Model Number: 91 of 180 with model ARIMA for Validation 3
# 91 - ARIMA with avg smape 1.43:
# Model Number: 92 of 180 with model GLS for Validation 3
# 92 - GLS with avg smape 1.13:
# Model Number: 93 of 180 with model AverageValueNaive for Validation 3
# 93 - AverageValueNaive with avg smape 1.37:
# Model Number: 94 of 180 with model AverageValueNaive for Validation 3
# 94 - AverageValueNaive with avg smape 1.37:
# Model Number: 95 of 180 with model AverageValueNaive for Validation 3
# 95 - AverageValueNaive with avg smape 1.37:
# Model Number: 96 of 180 with model Theta for Validation 3
# 96 - Theta with avg smape 8.88:
# Model Number: 97 of 180 with model Theta for Validation 3
# 97 - Theta with avg smape 1.43:
# Model Number: 98 of 180 with model Theta for Validation 3
# 98 - Theta with avg smape 1.42:
# Model Number: 99 of 180 with model NVAR for Validation 3
# 99 - NVAR with avg smape 4.59:
# Model Number: 100 of 180 with model NVAR for Validation 3
# 100 - NVAR with avg smape 4.55:
# Model Number: 101 of 180 with model MultivariateRegression for Validation 3
# 101 - MultivariateRegression with avg smape 1.31:
# Model Number: 102 of 180 with model NVAR for Validation 3
# 102 - NVAR with avg smape 1.82:
# Model Number: 103 of 180 with model NVAR for Validation 3
# 103 - NVAR with avg smape 4.79:
# Model Number: 104 of 180 with model LastValueNaive for Validation 3
# 104 - LastValueNaive with avg smape 12.83:
# Model Number: 105 of 180 with model NVAR for Validation 3
# 105 - NVAR with avg smape 3.23:
# Model Number: 106 of 180 with model NVAR for Validation 3
# 106 - NVAR with avg smape 4.79:
# Model Number: 107 of 180 with model NVAR for Validation 3
# 107 - NVAR with avg smape 2.68:
# Model Number: 108 of 180 with model ETS for Validation 3
# 108 - ETS with avg smape 3.51:
# Model Number: 109 of 180 with model NVAR for Validation 3
# 109 - NVAR with avg smape 2.61:
# Model Number: 110 of 180 with model NVAR for Validation 3
# 110 - NVAR with avg smape 2.4:
# Model Number: 111 of 180 with model ARIMA for Validation 3
# 111 - ARIMA with avg smape 1.47:
# Model Number: 112 of 180 with model ARIMA for Validation 3
# 112 - ARIMA with avg smape 1.36:
# Model Number: 113 of 180 with model ARIMA for Validation 3
# 113 - ARIMA with avg smape 1.37:
# Model Number: 114 of 180 with model ARIMA for Validation 3
# 114 - ARIMA with avg smape 2.09:
# Model Number: 115 of 180 with model ARIMA for Validation 3
# 115 - ARIMA with avg smape 2.06:
# Model Number: 116 of 180 with model GLS for Validation 3
# 116 - GLS with avg smape 1.37:
# Model Number: 117 of 180 with model MultivariateRegression for Validation 3
# 117 - MultivariateRegression with avg smape 1.58:
# Model Number: 118 of 180 with model MultivariateRegression for Validation 3
# 118 - MultivariateRegression with avg smape 1.58:
# Model Number: 119 of 180 with model Theta for Validation 3
# 119 - Theta with avg smape 8.03:
# Model Number: 120 of 180 with model LastValueNaive for Validation 3
# 120 - LastValueNaive with avg smape 12.83:
# Model Number: 121 of 180 with model GLM for Validation 3
# 121 - GLM with avg smape 1.37:
# Model Number: 122 of 180 with model ETS for Validation 3
# ETS error ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# ETS failed on Close with ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\genmod\families\family.py:1342: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
# 122 - ETS with avg smape 1.37:
# Model Number: 123 of 180 with model ETS for Validation 3
# 123 - ETS with avg smape 1.37:
# Model Number: 124 of 180 with model ETS for Validation 3
# 124 - ETS with avg smape 2.09:
# Model Number: 125 of 180 with model Theta for Validation 3
# 125 - Theta with avg smape 1.36:
# Model Number: 126 of 180 with model GLS for Validation 3
# 126 - GLS with avg smape 1.37:
# Model Number: 127 of 180 with model GLM for Validation 3
# 127 - GLM with avg smape 1.37:
# Model Number: 128 of 180 with model GLM for Validation 3
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\genmod\families\links.py:187: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\genmod\families\links.py:187: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# 128 - GLM with avg smape 1.37:
# Model Number: 129 of 180 with model GLM for Validation 3
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\genmod\families\links.py:187: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# 129 - GLM with avg smape 1.37:
# Model Number: 130 of 180 with model MultivariateRegression for Validation 3
# 130 - MultivariateRegression with avg smape 2.06:
# Model Number: 131 of 180 with model Theta for Validation 3
# 131 - Theta with avg smape 1.37:
# Model Number: 132 of 180 with model Theta for Validation 3
# 132 - Theta with avg smape 1.37:
# Model Number: 133 of 180 with model Theta for Validation 3
# 133 - Theta with avg smape 1.37:
# Model Number: 134 of 180 with model ConstantNaive for Validation 3
# 134 - ConstantNaive with avg smape 1.4:
# Model Number: 135 of 180 with model ConstantNaive for Validation 3
# 135 - ConstantNaive with avg smape 1.4:
# Model Number: 136 of 180 with model ConstantNaive for Validation 3
# 136 - ConstantNaive with avg smape 1.4:
# Model Number: 137 of 180 with model ConstantNaive for Validation 3
# 137 - ConstantNaive with avg smape 1.37:
# Model Number: 138 of 180 with model ConstantNaive for Validation 3
# 138 - ConstantNaive with avg smape 1.37:
# Model Number: 139 of 180 with model ConstantNaive for Validation 3
# 139 - ConstantNaive with avg smape 1.37:
# Model Number: 140 of 180 with model ConstantNaive for Validation 3
# 140 - ConstantNaive with avg smape 6.18:
# Model Number: 141 of 180 with model ConstantNaive for Validation 3
# 141 - ConstantNaive with avg smape 1.37:
# Model Number: 142 of 180 with model ConstantNaive for Validation 3
# 142 - ConstantNaive with avg smape 1.37:
# Model Number: 143 of 180 with model ARDL for Validation 3
# 143 - ARDL with avg smape 1.9:
# Model Number: 144 of 180 with model UnobservedComponents for Validation 3
# 144 - UnobservedComponents with avg smape 1.84:
# Model Number: 145 of 180 with model UnobservedComponents for Validation 3
# 145 - UnobservedComponents with avg smape 1.84:
# Model Number: 146 of 180 with model UnobservedComponents for Validation 3
# 146 - UnobservedComponents with avg smape 2.24:
# Model Number: 147 of 180 with model WindowRegression for Validation 3
# 147 - WindowRegression with avg smape 1.19:
# Model Number: 148 of 180 with model ARDL for Validation 3
# 148 - ARDL with avg smape 4.32:
# Model Number: 149 of 180 with model ARDL for Validation 3
# 149 - ARDL with avg smape 5.01:
# Model Number: 150 of 180 with model GLM for Validation 3
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\genmod\families\links.py:187: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# 150 - GLM with avg smape 1.37:
# Model Number: 151 of 180 with model WindowRegression for Validation 3
# 151 - WindowRegression with avg smape 2.9:
# Model Number: 152 of 180 with model GLS for Validation 3
# 152 - GLS with avg smape 1.84:
# Model Number: 153 of 180 with model UnobservedComponents for Validation 3
# 153 - UnobservedComponents with avg smape 7.04:
# Model Number: 154 of 180 with model ARDL for Validation 3
# 154 - ARDL with avg smape 1.96:
# Model Number: 155 of 180 with model UnobservedComponents for Validation 3
# 155 - UnobservedComponents with avg smape 6.54:
# Model Number: 156 of 180 with model WindowRegression for Validation 3
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 156 - WindowRegression with avg smape 1.45:
# Model Number: 157 of 180 with model GLM for Validation 3
# 157 - GLM with avg smape 1.37:
# Model Number: 158 of 180 with model WindowRegression for Validation 3
# 158 - WindowRegression with avg smape 1.19:
# Model Number: 159 of 180 with model WindowRegression for Validation 3
# 159 - WindowRegression with avg smape 1.19:
# Model Number: 160 of 180 with model ARDL for Validation 3
# 160 - ARDL with avg smape 5.69:
# Model Number: 161 of 180 with model WindowRegression for Validation 3
# 161 - WindowRegression with avg smape 3.61:
# Model Number: 162 of 180 with model ARDL for Validation 3
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 162 - ARDL with avg smape 1.06:
# Model Number: 163 of 180 with model ARDL for Validation 3
# 163 - ARDL with avg smape 0.99:
# Model Number: 164 of 180 with model WindowRegression for Validation 3
# 164 - WindowRegression with avg smape 2.98:
# Model Number: 165 of 180 with model WindowRegression for Validation 3
# 165 - WindowRegression with avg smape 2.7:
# Model Number: 166 of 180 with model ARDL for Validation 3
# 166 - ARDL with avg smape 2.3:
# Model Number: 167 of 180 with model GLM for Validation 3
# HolidayTransformer: no anomalies detected.
# 167 - GLM with avg smape 1.36:
# Model Number: 168 of 180 with model GLM for Validation 3
# HolidayTransformer: no anomalies detected.
# 168 - GLM with avg smape 1.37:
# Model Number: 169 of 180 with model GLM for Validation 3
# 169 - GLM with avg smape 1.37:
# Model Number: 170 of 180 with model DatepartRegression for Validation 3
# 170 - DatepartRegression with avg smape 5.88:
# Model Number: 171 of 180 with model DatepartRegression for Validation 3
# 171 - DatepartRegression with avg smape 5.68:
# Model Number: 172 of 180 with model DatepartRegression for Validation 3
# 172 - DatepartRegression with avg smape 5.82:
# Model Number: 173 of 180 with model DatepartRegression for Validation 3
# 173 - DatepartRegression with avg smape 1.37:
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model Number: 174 of 180 with model DatepartRegression for Validation 3
# 174 - DatepartRegression with avg smape 4.78:
# Model Number: 175 of 180 with model ARDL for Validation 3
# 175 - ARDL with avg smape 1.38:
# Model Number: 176 of 180 with model DatepartRegression for Validation 3
# 176 - DatepartRegression with avg smape 1.52:
# Model Number: 177 of 180 with model DatepartRegression for Validation 3
# 177 - DatepartRegression with avg smape 7.19:
# Model Number: 178 of 180 with model DatepartRegression for Validation 3
# C:\Users\Mhd Naqeeb\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 178 - DatepartRegression with avg smape 8.38:
# Model Number: 179 of 180 with model DatepartRegression for Validation 3
# 179 - DatepartRegression with avg smape 5.98:
# Model Number: 180 of 180 with model UnivariateRegression for Validation 3
# 180 - UnivariateRegression with avg smape 22.77:
# Model Number: 1810 with model Ensemble in generation 12 of Ensembles
# Model Number: 1811 with model Ensemble in generation 12 of Ensembles
# Model Number: 1812 with model Ensemble in generation 12 of Ensembles
# Model Number: 1813 with model Ensemble in generation 12 of Ensembles
# Model Number: 1814 with model Ensemble in generation 12 of Ensembles
# Model Number: 1815 with model Ensemble in generation 12 of Ensembles
# Model Number: 1816 with model Ensemble in generation 12 of Ensembles
# Model Number: 1817 with model Ensemble in generation 12 of Ensembles
# Validation Round: 1
# Model Number: 1 of 8 with model Ensemble for Validation 1
# 📈 1 - Ensemble with avg smape 0.89:
# Model Number: 2 of 8 with model Ensemble for Validation 1
# 2 - Ensemble with avg smape 1.11:
# Model Number: 3 of 8 with model Ensemble for Validation 1
# 3 - Ensemble with avg smape 3.62:
# Model Number: 4 of 8 with model Ensemble for Validation 1
# 4 - Ensemble with avg smape 1.02:
# Model Number: 5 of 8 with model Ensemble for Validation 1
# 5 - Ensemble with avg smape 0.9:
# Model Number: 6 of 8 with model Ensemble for Validation 1
# 6 - Ensemble with avg smape 1.11:
# Model Number: 7 of 8 with model Ensemble for Validation 1
# 7 - Ensemble with avg smape 0.92:
# Model Number: 8 of 8 with model Ensemble for Validation 1
# 8 - Ensemble with avg smape 0.93:
# Validation Round: 2
# Model Number: 1 of 8 with model Ensemble for Validation 2
# 📈 1 - Ensemble with avg smape 4.17:
# Model Number: 2 of 8 with model Ensemble for Validation 2
# 2 - Ensemble with avg smape 4.75:
# Model Number: 3 of 8 with model Ensemble for Validation 2
# 📈 3 - Ensemble with avg smape 3.39:
# Model Number: 4 of 8 with model Ensemble for Validation 2
# 4 - Ensemble with avg smape 4.22:
# Model Number: 5 of 8 with model Ensemble for Validation 2
# 5 - Ensemble with avg smape 4.17:
# Model Number: 6 of 8 with model Ensemble for Validation 2
# 6 - Ensemble with avg smape 4.53:
# Model Number: 7 of 8 with model Ensemble for Validation 2
# 7 - Ensemble with avg smape 4.07:
# Model Number: 8 of 8 with model Ensemble for Validation 2
# 8 - Ensemble with avg smape 4.1:
# Validation Round: 3
# Model Number: 1 of 8 with model Ensemble for Validation 3
# 📈 1 - Ensemble with avg smape 1.32:
# Model Number: 2 of 8 with model Ensemble for Validation 3
# 📈 2 - Ensemble with avg smape 1.03:
# Model Number: 3 of 8 with model Ensemble for Validation 3
# 3 - Ensemble with avg smape 2.34:
# Model Number: 4 of 8 with model Ensemble for Validation 3
# 4 - Ensemble with avg smape 1.96:
# Model Number: 5 of 8 with model Ensemble for Validation 3
# 5 - Ensemble with avg smape 1.33:
# Model Number: 6 of 8 with model Ensemble for Validation 3
# 6 - Ensemble with avg smape 1.48:
# Model Number: 7 of 8 with model Ensemble for Validation 3
# 7 - Ensemble with avg smape 1.49:
# Model Number: 8 of 8 with model Ensemble for Validation 3
# 8 - Ensemble with avg smape 1.46:
# DogeCoin Price Prediction
#                Close
# 2023-06-02  0.071660
# 2023-06-03  0.071858
# 2023-06-04  0.071844
# 2023-06-05  0.072052
# 2023-06-06  0.072161
# 2023-06-07  0.072136
# 2023-06-08  0.072799
# 2023-06-09  0.073074
# 2023-06-10  0.073428
# 2023-06-11  0.073533
